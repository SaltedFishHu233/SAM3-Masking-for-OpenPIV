# %% [markdown]
# # OpenPIVwSAM3 Description
#
# This sections shows the integrated workflow of SAM3 into the original OpenPIV-Python-CPU workflow.

# %% [markdown]
# ## PIV and SAM3 Integration Setup
#
# This section imports the required dependencies for particle image velocimetry (PIV) processing, SAM3-based segmentation, and general image analysis workflows. The environment is prepared by loading OpenCV, NumPy, Matplotlib, and PyTorch, along with the CPU-based OpenPIV implementation and a custom SAM3 interface module.
#
# Finally, GPU memory cache is cleared to ensure stable execution for subsequent processing steps.

# %%
#@title Import the needed libraries
#@markdown Run this block to import the dependencies.
import pkg_resources
import os
from glob import glob
import cv2
import time
import matplotlib.pyplot as plt
# %matplotlib inline
from openpiv_cpu.cpu_process import piv_cpu

from Scripts.SAM3Interface import SAM3Mask
import numpy as np

import torch

torch.cuda.empty_cache()
# Out:
# /tmp/ipykernel_31208/3460331903.py:3: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %% [markdown]
# ## PIV Frame Loading and Comparison
#
# Two sequential PIV frames are loaded from disk for motion analysis. Both images are read in their original bit depth and displayed side-by-side using a grayscale colormap to enable visual comparison of particle displacement between frames.
#
# Axis ticks are standardized across both images to provide spatial reference and improve interpretability of the flow field region during analysis.

# %%
Name1="Frame_00000.tif" #Change name for PIV image used to generate mask
Name2="Frame_00001.tif" #Change name for PIV image used to generate mask
InputPath=os.path.join(os.getcwd(),"input")
GenPath1=os.path.join(os.getcwd(),"input",Name1)
GenPath2=os.path.join(os.getcwd(),"input",Name2)
OutPath=os.path.join(os.getcwd(), "Temp.png")

frame_a  = cv2.imread(GenPath1, cv2.IMREAD_ANYDEPTH)
frame_b  = cv2.imread(GenPath2, cv2.IMREAD_ANYDEPTH)

fig, axs = plt.subplots(1, 2, figsize=(12,10))
axs[0].imshow(frame_a, cmap=plt.cm.gray)
axs[1].imshow(frame_b, cmap=plt.cm.gray)

# Modify tick labels and ticks.
tick_step = 250
ht, wd = frame_a.shape
for ax in axs:
    ax.set_xticks(range(0, wd, 2 * tick_step))
    ax.set_yticks(range(0, ht, tick_step))

plt.show()

# %% [markdown]
# ## SAM3 Mask Generation and Overlay Visualization
#
# A segmentation mask is generated using a SAM3-based interface with a text prompt to isolate the target structure in the image. The resulting binary mask is converted into an 8-bit format and colorized for visualization.
#
# The mask is then overlaid onto the original image using alpha blending, allowing the segmented region to be highlighted while preserving the underlying image structure for contextual interpretation.

# %%
MaskOut=SAM3Mask(GenPath1,"Black Shape")

Source = cv2.imread(GenPath1)

CroppedMask=MaskOut.astype(np.uint8) * 255
color_mask = cv2.cvtColor(CroppedMask, cv2.COLOR_GRAY2BGR)
color_mask[MaskOut] = [255, 0, 0] # Blue BGR

img = cv2.addWeighted(color_mask, 0.3, Source, 1, 0)

image_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(image_rgb)
# Out:
# Is CUDA available: True
# Current device: 0
# Device name: NVIDIA GeForce RTX 3070 Laptop GPU
# Processing images from: /home/leo/SAM3OpenPIV/SAM3-Masking-for-OpenPIV/input/Frame_00000.tif
# Depth: 2052
# Height: 4603
# Width: 3
# Detected
# tensor([0.9453], device='cuda:0', dtype=torch.bfloat16)

# %% [markdown]
# ## PIV Processing and Velocity Field Computation
#
# The particle image velocimetry (PIV) pipeline is configured by defining the frame dimensions, interrogation window sizes, and search iteration parameters. A segmentation mask is applied to restrict computation to the region of interest.
#
# The PIV algorithm is then initialized and executed on a pair of sequential frames to compute the velocity field. The resulting displacement components are corrected for coordinate orientation, and computation time is recorded for performance evaluation. Finally, invalid or low-confidence vector locations are identified for potential filtering or post-processing.

# %% [markdown]
# ## PIV Velocity Field Visualization
#
# The computed velocity field is visualized using a quiver plot, where vectors represent local flow direction and magnitude. Reliable and unreliable vectors are displayed using different colors to distinguish valid measurements from filtered or low-confidence results.
#
# The spatial domain is aligned using consistent axis limits and tick spacing to match the physical scale of the experiment. Finally, the segmentation mask is overlaid to highlight the region excluded from or included in the flow analysis, providing spatial context for the velocity field.

# %%
# PIV settings
frame_shape = (2052, 4603) 
min_search_size = 16 
search_size_iters = (1, 2, 2,) 
mask = CroppedMask 
for tol in range (7):
    # PIV settings
    ttol=0.5+tol*0.25
    name="S3"+str(round(ttol*100))+".png"
    frame_shape = (2052, 4603) 
    min_search_size = 16 
    search_size_iters = (1, 2, 2,) 
    mask = CroppedMask 
    # Perform PIV processing
    # Initialize the process.
    process = piv_cpu(frame_shape,
                      min_search_size=16,
                      search_size_iters=(1, 2, 2),
                      mask=mask,
                      median_tol=ttol,
                      s2n_tol=None)
    
    # Get the field coordinates.
    x, y = process.coords
    
    # Invert the y axis.Conclusions
    y = y[::-1]
    
    # Process the images.
    start_time = time.time()
    u, v = process(frame_a, frame_b)
    v = -v
    
    # Printout the computation time.
    process_time = time.time() - start_time
    print('Computation time for {} image pair was {:.3f} s.'.format(1, process_time))
    
    # Get the locations of the unreliable vectors.
    loc = process.val_locations
    _loc = ~loc
    
    print(f"Tol: {ttol}")
    print(f"Invalid Vectors: {np.count_nonzero(loc)}") 
    print(f"Total Vectors: {np.count_nonzero(_loc)+np.count_nonzero(loc)}") 
    print(f"Next")
    # Create a figure.
    fig, ax = plt.subplots(figsize=(11, 11))
    ax.set_aspect(1)
    vector_width = 0.0005
    vector_scale = 1000
    
    # Modify tick labels and ticks.
    tick_step = 250
    ax.set_xticks(range(0, int(x[0, -1]), 2 * tick_step))
    ax.set_yticks(range(0, int(y[0, -1]), tick_step))
    
    # Adjust the axis limits to the minimum and maximum range.
    ax.set_xlim(x.min(), x.max())
    ax.set_ylim(y.min(), y.max())
    
    # Show the quiver plot.
    ax.quiver(x[_loc], y[_loc], u[_loc], v[_loc], color="b", width=vector_width, scale=vector_scale)
    ax.quiver(x[loc], y[loc], u[loc], v[loc], color="r", width=vector_width, scale=vector_scale)
    ax.set_title(f"Separated flow")
    
    # Show the mask on the plot.
    ax.imshow(~mask, cmap='gray', alpha=0.5, extent=[x.min(), x.max(), y.min(), y.max()])
    fig.savefig(name, bbox_inches='tight')
# Out:
# Computation time for 1 image pair was 13.923 s.
# Tol: 0.5
# Invalid Vectors: 5129
# Total Vectors: 146370
# Next
# Computation time for 1 image pair was 12.427 s.
# Tol: 0.75
# Invalid Vectors: 2336
# Total Vectors: 146370
# Next
# Computation time for 1 image pair was 13.116 s.
# Tol: 1.0
# Invalid Vectors: 1457
# Total Vectors: 146370
# Next
# Computation time for 1 image pair was 11.879 s.
# Tol: 1.25
# Invalid Vectors: 1104
# Total Vectors: 146370
# Next
# Computation time for 1 image pair was 11.948 s.
# Tol: 1.5
# Invalid Vectors: 855
# Total Vectors: 146370
# Next
# Computation time for 1 image pair was 12.651 s.
# Tol: 1.75
# Invalid Vectors: 709
# Total Vectors: 146370
# Next
# Computation time for 1 image pair was 13.979 s.
# Tol: 2.0
# Invalid Vectors: 603
# Total Vectors: 146370
# Next

# %%
torch.cuda.empty_cache()

# %%
# PIV settings
frame_shape = (2052, 4603) 
min_search_size = 16 
search_size_iters = (1, 2, 2,) 
mask = CroppedMask 
for tol in range (7):
    # PIV settings
    ttol=1+tol*0.25
    name="S3Lim"+str(round(ttol*100))+".png"
    frame_shape = (2052, 4603) 
    min_search_size = 16 
    search_size_iters = (1, 2, 2,) 
    mask = CroppedMask 
    # Perform PIV processing
    # Initialize the process.
    process = piv_cpu(frame_shape,
                      min_search_size=16,
                      search_size_iters=(1, 2, 2),
                      mask=mask,
                      median_tol=None,
                      s2n_tol=ttol)
    
    # Get the field coordinates.
    x, y = process.coords
    
    # Invert the y axis.Conclusions
    y = y[::-1]
    
    # Process the images.
    start_time = time.time()
    u, v = process(frame_a, frame_b)
    v = -v
    
    # Printout the computation time.
    process_time = time.time() - start_time
    print('Computation time for {} image pair was {:.3f} s.'.format(1, process_time))
    
    # Get the locations of the unreliable vectors.
    loc = process.val_locations
    _loc = ~loc
    
    print(f"Tol: {ttol}")
    print(f"Invalid Vectors: {np.count_nonzero(loc)}") 
    print(f"Total Vectors: {np.count_nonzero(_loc)+np.count_nonzero(loc)}") 
    print(f"Next")
    # Create a figure.
    fig, ax = plt.subplots(figsize=(11, 11))
    ax.set_aspect(1)
    vector_width = 0.0005
    vector_scale = 1000
    
    # Modify tick labels and ticks.
    tick_step = 250
    ax.set_xticks(range(0, int(x[0, -1]), 2 * tick_step))
    ax.set_yticks(range(0, int(y[0, -1]), tick_step))
    
    # Adjust the axis limits to the minimum and maximum range.
    ax.set_xlim(2000, 3000)
    ax.set_ylim(250, 750)
    
    # Show the quiver plot.
    ax.quiver(x[_loc], y[_loc], u[_loc], v[_loc], color="b", width=vector_width, scale=vector_scale/5)
    ax.quiver(x[loc], y[loc], u[loc], v[loc], color="r", width=vector_width, scale=vector_scale/5)
    ax.set_title(f"Separated flow")
    
    # Show the mask on the plot.
    ax.imshow(~mask, cmap='gray', alpha=0.5, extent=[x.min(), x.max(), y.min(), y.max()])
    fig.savefig(name, bbox_inches='tight')
# Out:
# Computation time for 1 image pair was 16.965 s.
# Tol: 1.0
# Invalid Vectors: 0
# Total Vectors: 146370
# Next
# Computation time for 1 image pair was 13.503 s.
# Tol: 1.25
# Invalid Vectors: 973
# Total Vectors: 146370
# Next
# Computation time for 1 image pair was 13.933 s.
# Tol: 1.5
# Invalid Vectors: 2410
# Total Vectors: 146370
# Next
# Computation time for 1 image pair was 13.800 s.
# Tol: 1.75
# Invalid Vectors: 4010
# Total Vectors: 146370
# Next
# Computation time for 1 image pair was 17.792 s.
# Tol: 2.0
# Invalid Vectors: 6665
# Total Vectors: 146370
# Next
# Computation time for 1 image pair was 19.480 s.
# Tol: 2.25
# Invalid Vectors: 11280
# Total Vectors: 146370
# Next
# Computation time for 1 image pair was 25.584 s.
# Tol: 2.5
# Invalid Vectors: 17967
# Total Vectors: 146370
# Next
